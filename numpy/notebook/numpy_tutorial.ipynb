# %%
import numpy as np

# %%
arr=np.array([[1,4,5,6,2,3],[2,4,6,8,4,7]])
print(arr)
# Out:
# [[1 4 5 6 2 3]
#  [2 4 6 8 4 7]]

# %% [markdown]
# * **Shape gives the number of rows , columns**

# %%
arr.shape
# Out:
# (2, 6)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr[0,1]
arr[1,2]
# Out:
# 4
# np.int64(6)

# %%
arr[0,1]=99

# %%
arr
# Out:
# array([[ 1, 99,  5,  6,  2,  3],
#        [ 2,  4,  6,  8,  4,  7]])
