# %% [markdown]
# # AXIS
#
# * axis=0 for *rows* (top to down)
# * axis=1 for *columns* (left to right)

# %%
import numpy as np

# %%
x=[[1,2,3],[4,5,6],[7,1,0]]

# %%
arr=np.array(x)

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 1, 0]])

# %% [markdown]
# * sums all elements down the row

# %%
arr.sum(axis=0)
# Out:
# array([12,  8,  9])

# %% [markdown]
# * axis=1 sums element in a particular row , all the columns

# %%
arr.sum(axis=1)
# Out:
# array([ 6, 15,  8])

# %% [markdown]
# * **Transpose** the original matrix

# %%
arr.T
# Out:
# array([[1, 4, 7],
#        [2, 5, 1],
#        [3, 6, 0]])

# %% [markdown]
# * .flat is used for iterating in items of a matrice

# %%
arr.flat

# %%
for item in arr.flat:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 1
# 0

# %% [markdown]
# * **.size** gives total element count

# %%
arr.size
# Out:
# 9

# %% [markdown]
# * gives total bytes consumed

# %%
arr.nbytes
# Out:
# 72

# %%
one=np.array([1,3,5,6,34,6])

# %% [markdown]
# * argmax gives the index which contains the max value element

# %%
one.argmax()
# Out:
# np.int64(4)

# %%
one.argmin()
# Out:
# np.int64(0)

# %% [markdown]
# * gives indeces for sorting the array

# %%
one.argsort()
# Out:
# array([0, 1, 2, 3, 5, 4])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 1, 0]])

# %%
arr.argmin()
# Out:
# np.int64(8)

# %%
arr.argmax()
# Out:
# np.int64(6)

# %% [markdown]
# * argmax(axis=0) this gives the max value index in each row

# %%
arr.argmax(axis=0)
# Out:
# array([2, 1, 1])

# %%
arr.argmax(axis=1)
# Out:
# array([2, 2, 0])

# %%
arr.ravel()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 1, 0])

# %% [markdown]
# **Matrix Operations**

# %%
ar=np.array([[1, 2, 1],
       [4, 0, 6],
       [8, 1, 0]])

# %%
ar+arr
# Out:
# array([[ 2,  4,  4],
#        [ 8,  5, 12],
#        [15,  2,  0]])

# %%
[1,2]+[3,4]
# Out:
# [1, 2, 3, 4]

# %%
arr*ar
# Out:
# array([[ 1,  4,  3],
#        [16,  0, 36],
#        [56,  1,  0]])

# %%
arr-ar
# Out:
# array([[ 0,  0,  2],
#        [ 0,  5,  0],
#        [-1,  0,  0]])

# %%
np.sqrt(arr)
# Out:
# array([[1.        , 1.41421356, 1.73205081],
#        [2.        , 2.23606798, 2.44948974],
#        [2.64575131, 1.        , 0.        ]])

# %%
arr.sum()
# Out:
# np.int64(29)

# %%
arr.max()
# Out:
# np.int64(7)

# %%
arr.min()
# Out:
# np.int64(0)

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 1, 0]])

# %% [markdown]
# * index of element greater than 5

# %%
np.where(arr>5)
# Out:
# (array([1, 2]), array([2, 0]))

# %%
np.count_nonzero(arr)
# Out:
# np.int64(8)

# %%
np.nonzero(arr)
# Out:
# (array([0, 0, 0, 1, 1, 1, 2, 2]), array([0, 1, 2, 0, 1, 2, 0, 1]))

# %%
import sys

# %%
py_ar=[0,4,55,2]

# %%
np_ar=np.array(py_ar)

# %%
sys.getsizeof(1)*len(py_ar)
# Out:
# 112

# %%
np_ar.itemsize * np_ar.size
# Out:
# 32

# %% [markdown]
# * repeat elements in an array

# %%
a=np.array([1,2,3])
r1=np.repeat(a,3,axis=0)
print(r1)
# Out:
# [1 1 1 2 2 2 3 3 3]
