# %%
import numpy as np
import pandas as pd
import os
import lxml

# %% [markdown]
# * **CSV** for comma separated values in a file

# %%
pd.read_csv('t.txt')
# Out:
#     name  age   city
# 0  Ankit   20   Pune
# 1  Rahul   22  Delhi

# %%
pwd
# Out:
# 'd:\\Projects\\Python_for_ML\\pandas'

# %% [markdown]
# * can read the file also by using the entire path of the file

# %%
pd.read_csv("d:\\Projects\\Python_for_ML\\pandas\\t.txt")
# Out:
#     name  age   city
# 0  Ankit   20   Pune
# 1  Rahul   22  Delhi

# %%
a=pd.read_csv("d:\\Projects\\Python_for_ML\\pandas\\e.xlsx")

# %%
a
# Out:
#    ID   Name  Age  Course  Marks    City
# 0   1  Ankit   20  Python     85    Pune
# 1   2  Rahul   22    Java     78   Delhi
# 2   3   Neha   21      ML     92  Mumbai
# 3   4   Aman   23     C++     69  Jaipur
# 4   5  Pooja   20      DS     88  Indore

# %%
type(a)
# Out:
# pandas.DataFrame
