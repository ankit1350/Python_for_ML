# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
df
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
# 5              52      Meowth    Normal     NaN   40      45       35      40
# 6              94      Gengar     Ghost  Poison   60      65       60     130
# 7             130    Gyarados     Water  Flying   95     125       79      60
# 8             143     Snorlax    Normal     NaN  160     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# ...

# %% [markdown]
# * fitler the pokemons according to their speed

# %%
tall_pokemon=df[df["Speed"]>=50]
tall_pokemon
# Out:
#    Pokedex_Number        Name     Type1   Type2  HP  Attack  Defense  Sp_Atk  \
# 1               4  Charmander      Fire     NaN  39      52       43      60
# 3              25     Pikachu  Electric     NaN  35      55       40      50
# 5              52      Meowth    Normal     NaN  40      45       35      40
# 6              94      Gengar     Ghost  Poison  60      65       60     130
# 7             130    Gyarados     Water  Flying  95     125       79      60
#
#    Sp_Def  Speed  Generation  Legendary
# 1      50     65           1      False
# 3      50     90           1      False
# 5      40     90           1      False
# 6      75    110           1      False
# 7     100     81           1      False

# %%
l_pokemon=df[df["Legendary"]==True]
l_pokemon
# Out:
# Empty DataFrame
# Columns: [Pokedex_Number, Name, Type1, Type2, HP, Attack, Defense, Sp_Atk, Sp_Def, Speed, Generation, Legendary]
# Index: []

# %%
water_pokemon=df[df["Type1"]=="Water"]
water_pokemon
# Out:
#    Pokedex_Number      Name  Type1   Type2  HP  Attack  Defense  Sp_Atk  \
# 2               7  Squirtle  Water     NaN  44      48       65      50
# 7             130  Gyarados  Water  Flying  95     125       79      60
#
#    Sp_Def  Speed  Generation  Legendary
# 2      64     43           1      False
# 7     100     81           1      False

# %%
w_pokemon=df[(df["Type1"]=="Water") | (df["Type2"]=="Water")]
w_pokemon
# Out:
#    Pokedex_Number      Name  Type1   Type2  HP  Attack  Defense  Sp_Atk  \
# 2               7  Squirtle  Water     NaN  44      48       65      50
# 7             130  Gyarados  Water  Flying  95     125       79      60
#
#    Sp_Def  Speed  Generation  Legendary
# 2      64     43           1      False
# 7     100     81           1      False

# %%
f_pokemon=df[(df["Type1"]=="Water") & (df["Type2"]=="Flying")]
f_pokemon
# Out:
#    Pokedex_Number      Name  Type1   Type2  HP  Attack  Defense  Sp_Atk  \
# 7             130  Gyarados  Water  Flying  95     125       79      60
#
#    Sp_Def  Speed  Generation  Legendary
# 7     100     81           1      False
