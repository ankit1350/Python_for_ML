# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
df
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
# 5              52      Meowth    Normal     NaN   40      45       35      40
# 6              94      Gengar     Ghost  Poison   60      65       60     130
# 7             130    Gyarados     Water  Flying   95     125       79      60
# 8             143     Snorlax    Normal     NaN  160     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# ...

# %%
df.shape
# Out:
# (9, 12)

# %%
df.head()
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# 3      50     90           1      False
# 4      25     20           1      False

# %%
df.head(7)
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
# 5              52      Meowth    Normal     NaN   40      45       35      40
# 6              94      Gengar     Ghost  Poison   60      65       60     130
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# 3      50     90           1      False
# 4      25     20           1      False
# 5      40     90           1      False
# 6      75    110           1      False

# %%
df.to_string()
# Out:
# '   Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary\n0               1   Bulbasaur     Grass  Poison   45      49       49      65      65     45           1      False\n1               4  Charmander      Fire     NaN   39      52       43      60      50     65           1      False\n2               7    Squirtle     Water     NaN   44      48       65      50      64     43           1      False\n3              25     Pikachu  Electric     NaN   35      55       40      50      50     90           1      False\n4              39  Jigglypuff    Normal   Fairy  115      45       20      45      25     20           1      False\n5              52      Meowth    Normal     NaN   40      45       35      40      40     90           1      False\n6              94      Gengar     Ghost  Poison   60      65       60     130      75    110           1      False\n7             130    Gyarados     Water  Flying   95     125 
# ...

# %%
af=pd.read_json("data.json")
af
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
# 5              52      Meowth    Normal     NaN   40      45       35      40
# 6              94      Gengar     Ghost  Poison   60      65       60     130
# 7             130    Gyarados     Water  Flying   95     125       79      60
# 8             143     Snorlax    Normal     NaN  160     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# ...

# %% [markdown]
# **selection**

# %%
df["Name"]
# Out:
# 0     Bulbasaur
# 1    Charmander
# 2      Squirtle
# 3       Pikachu
# 4    Jigglypuff
# 5        Meowth
# 6        Gengar
# 7      Gyarados
# 8       Snorlax
# Name: Name, dtype: str

# %%
df['Name'].to_string()
# Out:
# '0     Bulbasaur\n1    Charmander\n2      Squirtle\n3       Pikachu\n4    Jigglypuff\n5        Meowth\n6        Gengar\n7      Gyarados\n8       Snorlax'

# %%
df["Type1"]
# Out:
# 0       Grass
# 1        Fire
# 2       Water
# 3    Electric
# 4      Normal
# 5      Normal
# 6       Ghost
# 7       Water
# 8      Normal
# Name: Type1, dtype: str

# %%
df[["Name","Type1"]]
# Out:
#          Name     Type1
# 0   Bulbasaur     Grass
# 1  Charmander      Fire
# 2    Squirtle     Water
# 3     Pikachu  Electric
# 4  Jigglypuff    Normal
# 5      Meowth    Normal
# 6      Gengar     Ghost
# 7    Gyarados     Water
# 8     Snorlax    Normal

# %% [markdown]
# * selection by rows

# %%
df.loc[0]
# Out:
# Pokedex_Number            1
# Name              Bulbasaur
# Type1                 Grass
# Type2                Poison
# HP                       45
# Attack                   49
# Defense                  49
# Sp_Atk                   65
# Sp_Def                   65
# Speed                    45
# Generation                1
# Legendary             False
# Name: 0, dtype: object

# %%
df.loc["Name":"Bulbasaur"]
# Out:
# Empty DataFrame
# Columns: [Pokedex_Number, Name, Type1, Type2, HP, Attack, Defense, Sp_Atk, Sp_Def, Speed, Generation, Legendary]
# Index: []

# %%
df.loc[0,["Type1","Type2"]]
# Out:
# Type1     Grass
# Type2    Poison
# Name: 0, dtype: str

# %% [markdown]
# * access the first 10 rows

# %%
df.iloc[0:11]
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
# 5              52      Meowth    Normal     NaN   40      45       35      40
# 6              94      Gengar     Ghost  Poison   60      65       60     130
# 7             130    Gyarados     Water  Flying   95     125       79      60
# 8             143     Snorlax    Normal     NaN  160     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# ...

# %% [markdown]
# * access the first 10 even rows

# %%
df.iloc[0:11:2]
# Out:
#    Pokedex_Number        Name   Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur   Grass  Poison   45      49       49      65
# 2               7    Squirtle   Water     NaN   44      48       65      50
# 4              39  Jigglypuff  Normal   Fairy  115      45       20      45
# 6              94      Gengar   Ghost  Poison   60      65       60     130
# 8             143     Snorlax  Normal     NaN  160     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 2      64     43           1      False
# 4      25     20           1      False
# 6      75    110           1      False
# 8     110     30           1      False

# %% [markdown]
# * access the even rows with only 3 columns

# %%
df.iloc[0:11:2,0:3]
# Out:
#    Pokedex_Number        Name   Type1
# 0               1   Bulbasaur   Grass
# 2               7    Squirtle   Water
# 4              39  Jigglypuff  Normal
# 6              94      Gengar   Ghost
# 8             143     Snorlax  Normal

# %%
pokemon=int(input("Enter a pokemon index:"))
try:
    print(df.loc[pokemon])
except KeyError:
    print(f"{pokemon} not found")
# Out:
# Pokedex_Number            1
# Name              Bulbasaur
# Type1                 Grass
# Type2                Poison
# HP                       45
# Attack                   49
# Defense                  49
# Sp_Atk                   65
# Sp_Def                   65
# Speed                    45
# Generation                1
# Legendary             False
# Name: 0, dtype: object
