# %% [markdown]
# ### series is a 1D labelled data.

# %%
import pandas as pd
import numpy as np

# %%
data=[234,45,3,63,64]
series=pd.Series(data)
series
# Out:
# 0    234
# 1     45
# 2      3
# 3     63
# 4     64
# dtype: int64

# %% [markdown]
# ### Dataframe is 2D

# %%
d=pd.DataFrame(series)
d
# Out:
#      0
# 0  234
# 1   45
# 2    3
# 3   63
# 4   64

# %%
a=pd.Series(data,index=['a','b','c','d','e'])
a
# Out:
# a    234
# b     45
# c      3
# d     63
# e     64
# dtype: int64

# %%
a.loc["d"]=5555
a
# Out:
# a     234
# b      45
# c       3
# d    5555
# e      64
# dtype: int64

# %%
series
# Out:
# 0    234
# 1     45
# 2      3
# 3     63
# 4     64
# dtype: int64

# %%
print(series.iloc[2])
print(series.iloc[4])
# Out:
# 3
# 64

# %%
series[series>=63]
# Out:
# 0    234
# 3     63
# 4     64
# dtype: int64

# %% [markdown]
# * the index is the "key" in a dictionary

# %%
calories={"day1":232,"day2":2342,"day3":3929}
b=pd.Series(calories)
b
# Out:
# day1     232
# day2    2342
# day3    3929
# dtype: int64

# %%
b.loc["day3"]
# Out:
# np.int64(3929)

# %%
b.loc["day3"]-=1000

# %%
b
# Out:
# day1     232
# day2    2342
# day3    2429
# dtype: int64

# %%
b[b>=2000]
# Out:
# day2    2342
# day3    2429
# dtype: int64
