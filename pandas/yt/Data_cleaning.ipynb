# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")
df
# Out:
#    Pokedex_Number        Name     Type1   Type2   HP  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison   45      49       49      65
# 1               4  Charmander      Fire     NaN   39      52       43      60
# 2               7    Squirtle     Water     NaN   44      48       65      50
# 3              25     Pikachu  Electric     NaN   35      55       40      50
# 4              39  Jigglypuff    Normal   Fairy  115      45       20      45
# 5              52      Meowth    Normal     NaN   40      45       35      40
# 6              94      Gengar     Ghost  Poison   60      65       60     130
# 7             130    Gyarados     Water  Flying   95     125       79      60
# 8             143     Snorlax    Normal     NaN  160     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# ...

# %% [markdown]
# * drop a particular irrelevant column

# %%
df=df.drop(columns=["HP"])
df
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Defense  Sp_Atk  \
# 0               1   Bulbasaur     Grass  Poison      49       49      65
# 1               4  Charmander      Fire     NaN      52       43      60
# 2               7    Squirtle     Water     NaN      48       65      50
# 3              25     Pikachu  Electric     NaN      55       40      50
# 4              39  Jigglypuff    Normal   Fairy      45       20      45
# 5              52      Meowth    Normal     NaN      45       35      40
# 6              94      Gengar     Ghost  Poison      65       60     130
# 7             130    Gyarados     Water  Flying     125       79      60
# 8             143     Snorlax    Normal     NaN     110       65      65
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      50     65           1      False
# 2      64     43           1      False
# 3      50     90           1      False
# ...

# %%
df=df.drop(columns=["Defense","Speed"])
df
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Sp_Atk  Sp_Def  \
# 0               1   Bulbasaur     Grass  Poison      49      65      65
# 1               4  Charmander      Fire     NaN      52      60      50
# 2               7    Squirtle     Water     NaN      48      50      64
# 3              25     Pikachu  Electric     NaN      55      50      50
# 4              39  Jigglypuff    Normal   Fairy      45      45      25
# 5              52      Meowth    Normal     NaN      45      40      40
# 6              94      Gengar     Ghost  Poison      65     130      75
# 7             130    Gyarados     Water  Flying     125      60     100
# 8             143     Snorlax    Normal     NaN     110      65     110
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False
# 6           1      False
# 7           1      False
# ...

# %% [markdown]
# * look in Type 2 column
#     * if found a null value:
#         * drop the entire row

# %%
# df.dropna(subset=["Type2"])

# %% [markdown]
# * **fillna** fill any non available value in Type 2 = None

# %%
df.fillna({"Type2":"None"})
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Sp_Atk  Sp_Def  \
# 0               1   Bulbasaur     Grass  Poison      49      65      65
# 1               4  Charmander      Fire    None      52      60      50
# 2               7    Squirtle     Water    None      48      50      64
# 3              25     Pikachu  Electric    None      55      50      50
# 4              39  Jigglypuff    Normal   Fairy      45      45      25
# 5              52      Meowth    Normal    None      45      40      40
# 6              94      Gengar     Ghost  Poison      65     130      75
# 7             130    Gyarados     Water  Flying     125      60     100
# 8             143     Snorlax    Normal    None     110      65     110
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False
# 6           1      False
# 7           1      False
# ...

# %% [markdown]
# * fix any inconsistent value

# %%
df["Type1"]=df["Type1"].replace({"Grass":"GRASS"})

# %%
df
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Sp_Atk  Sp_Def  \
# 0               1   Bulbasaur     GRASS  Poison      49      65      65
# 1               4  Charmander      Fire     NaN      52      60      50
# 2               7    Squirtle     Water     NaN      48      50      64
# 3              25     Pikachu  Electric     NaN      55      50      50
# 4              39  Jigglypuff    Normal   Fairy      45      45      25
# 5              52      Meowth    Normal     NaN      45      40      40
# 6              94      Gengar     Ghost  Poison      65     130      75
# 7             130    Gyarados     Water  Flying     125      60     100
# 8             143     Snorlax    Normal     NaN     110      65     110
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False
# 6           1      False
# 7           1      False
# ...

# %%
df["Type1"]=df["Type1"].replace({"Fire":"FIRE","Water":"WATER"})
df
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Sp_Atk  Sp_Def  \
# 0               1   Bulbasaur     GRASS  Poison      49      65      65
# 1               4  Charmander      FIRE     NaN      52      60      50
# 2               7    Squirtle     WATER     NaN      48      50      64
# 3              25     Pikachu  Electric     NaN      55      50      50
# 4              39  Jigglypuff    Normal   Fairy      45      45      25
# 5              52      Meowth    Normal     NaN      45      40      40
# 6              94      Gengar     Ghost  Poison      65     130      75
# 7             130    Gyarados     WATER  Flying     125      60     100
# 8             143     Snorlax    Normal     NaN     110      65     110
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False
# 6           1      False
# 7           1      False
# ...

# %% [markdown]
# * standardize text

# %%
df["Name"]=df["Name"].str.upper()
df
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Sp_Atk  Sp_Def  \
# 0               1   BULBASAUR     GRASS  Poison      49      65      65
# 1               4  CHARMANDER      FIRE     NaN      52      60      50
# 2               7    SQUIRTLE     WATER     NaN      48      50      64
# 3              25     PIKACHU  Electric     NaN      55      50      50
# 4              39  JIGGLYPUFF    Normal   Fairy      45      45      25
# 5              52      MEOWTH    Normal     NaN      45      40      40
# 6              94      GENGAR     Ghost  Poison      65     130      75
# 7             130    GYARADOS     WATER  Flying     125      60     100
# 8             143     SNORLAX    Normal     NaN     110      65     110
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False
# 6           1      False
# 7           1      False
# ...

# %% [markdown]
# * fix the data type

# %%
df["Generation"]=df["Generation"].astype(bool)
df
# Out:
#    Pokedex_Number        Name     Type1   Type2  Attack  Sp_Atk  Sp_Def  \
# 0               1   BULBASAUR     GRASS  Poison      49      65      65
# 1               4  CHARMANDER      FIRE     NaN      52      60      50
# 2               7    SQUIRTLE     WATER     NaN      48      50      64
# 3              25     PIKACHU  Electric     NaN      55      50      50
# 4              39  JIGGLYPUFF    Normal   Fairy      45      45      25
# 5              52      MEOWTH    Normal     NaN      45      40      40
# 6              94      GENGAR     Ghost  Poison      65     130      75
# 7             130    GYARADOS     WATER  Flying     125      60     100
# 8             143     SNORLAX    Normal     NaN     110      65     110
#
#    Generation  Legendary
# 0        True      False
# 1        True      False
# 2        True      False
# 3        True      False
# 4        True      False
# 5        True      False
# 6        True      False
# 7        True      False
# ...

# %% [markdown]
# * drop any duplicates present

# %%
df=df.drop_duplicates()
